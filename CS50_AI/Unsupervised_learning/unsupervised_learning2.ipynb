# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('Mall_Customers.csv')

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.sample()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 191         192  Female   32                 103                      69

# %%
df.tail()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 245         246    Male   30                 297                      69
# 246         247  Female   56                 311                      14
# 247         248    Male   29                 313                      90
# 248         249  Female   19                 316                      32
# 249         250  Female   31                 325                      86

# %%
df.describe()
# Out:
#        CustomerID        Age  Annual Income (k$)  Spending Score (1-100)
# count  250.000000  250.00000          250.000000              250.000000
# mean   125.500000   38.49200           95.592000               50.244000
# std     72.312977   13.17026           77.308758               27.289914
# min      1.000000   18.00000           15.000000                1.000000
# 25%     63.250000   29.00000           47.000000               27.000000
# 50%    125.500000   36.00000           70.000000               50.000000
# 75%    187.750000   47.75000          101.000000               74.000000
# max    250.000000   70.00000          325.000000               99.000000

# %%
X = df.iloc[:, [3, 4]].values

# %%
X.shape
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
# import scipy.cluster.hierarchy as sc
import scipy.cluster.heirarchy as sc # type: ignore
plt.figure(figsize=(10, 7))
dendrogram = sc.dendrogram(sc.linkage(X, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# %%
from sklearn.cluster import  AgglomerativeClustering

hca = AgglomerativeClustering(X)

# %%
plt.scatter(X[y_hca == 0, 0], X[y_hca == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_hca == 1, 0], X[y_hca == 1, 1], s = 100, c = 'green', label = 'Cluster 2')
plt.scatter(X[y_hca == 2, 0], X[y_hca == 2, 1], s = 100, c = 'blue', label = 'Cluster 3')
plt.scatter(X[y_hca == 3, 0], X[y_hca == 3, 1], s = 100, c = 'orange', label = 'Cluster 4')
plt.scatter(X[y_hca == 4, 0], X[y_hca == 4, 1], s = 100, c = 'black', label = 'Cluster 5')

plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
from sklearn.metrics import silhouette_score

silhouette_avg = silhouette_score(X, y_hca)
print(f'Silhouette Score: {silhouette_avg}')

# %%
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(X,y_hca)
print(f'Silhoutte Score: {silhouette_avg}')
