# %%
import numpy as np

A = np.array([[2,1],[3,4]])
A_inv = np.linalg.inv(A)
print(A_inv)
# Out:
# [[ 0.8 -0.2]
#  [-0.6  0.4]]

# %%
B = np.array([[1,4,3],[3,4,7],[8,0,5]])
B_det = np.linalg.det(B)
print(round(B_det))
# Out:
# 88

# %%
np.linalg.adjoint(B)
