# %%
biodata = {
    "name": "Bishal Shrestha",
    "age": 19,
    "nationality": "Nepali",
    "sex": 'M',
    "isMarried": False,
    "fav_movies": ["Intersellar","The dark Knight","Avengers Endgame", "Avenger's Infinity war", "KGF"]
}

# %%
print("Biodata keys: ",biodata.keys())
# Out:
# Biodata keys:  dict_keys(['name', 'age', 'nationality', 'sex', 'isMarried', 'fav_movies'])

# %%
print("Biodata values: ",biodata.values())
# Out:
# Biodata values:  dict_values(['Bishal Shrestha', 19, 'Nepali', 'M', False, ['Intersellar', 'The dark Knight', 'Avengers Endgame', "Avenger's Infinity war", 'KGF']])

# %%
info = {"height": 5.7}
biodata.update(info)
biodata
# Out:
# {'name': 'Bishal Shrestha',
#  'age': 19,
#  'nationality': 'Nepali',
#  'sex': 'M',
#  'isMarried': False,
#  'fav_movies': ['Intersellar',
#   'The dark Knight',
#   'Avengers Endgame',
#   "Avenger's Infinity war",
#   'KGF'],
#  5.7: 5.7,
#  'height': 5.7}

# %%
biodata.update({"education": "bachelor of computer science in Information and Technology"})
biodata.values()
# Out:
# dict_values(['Bishal Shrestha', 19, 'Nepali', 'M', False, ['Intersellar', 'The dark Knight', 'Avengers Endgame', "Avenger's Infinity war", 'KGF'], 5.7, 5.7, 'bachelor of computer science in Information and Technology'])
