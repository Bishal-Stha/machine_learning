# %%
import nltk
from nltk import sent_tokenize, word_tokenize

# %%
text = "An apple a day keeps the doctor away. A quick brown fox jumps over the lazy dog. A dog barks whereas cow moos."

words = word_tokenize(text.lower())
words
# Out:
# ['an',
#  'apple',
#  'a',
#  'day',
#  'keeps',
#  'the',
#  'doctor',
#  'away',
#  '.',
#  'a',
#  'quick',
#  'brown',
#  'fox',
#  'jumps',
#  'over',
#  'the',
#  'lazy',
#  'dog',
#  '.',
#  'a',
#  'dog',
#  'barks',
#  'whereas',
#  'cow',
#  'moos',
#  '.']

# %%
sentences = sent_tokenize(text)
sentences
# Out:
# ['An apple a day keeps the doctor away.',
#  'A quick brown fox jumps over the lazy dog.',
#  'A dog barks whereas cow moos.']

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()
print(porter.stem("jumps"))
# Out:
# jump

# %%
# create an object of class PorterStemmer
porter = PorterStemmer()
print(porter.stem("Communication"))
# Out:
# commun

# %%
from nltk.stem import WordNetLemmatizer
# create an object of class WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("plays", 'v'))
print(lemmatizer.lemmatize("played", 'v'))
print(lemmatizer.lemmatize("play", 'v'))
print(lemmatizer.lemmatize("playing", 'v'))
# Out:
# play
# play
# play
# play

# %%
# create an object of class WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("Communication", 'v'))
# Out:
# Communication

# %%
from nltk import pos_tag

text = "GeeksforGeeks is a Computer Science platform."
tokenized_text = word_tokenize(text)
tags = tokens_tag = pos_tag(tokenized_text)
tags
# Out:
# [('GeeksforGeeks', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('Computer', 'NNP'),
#  ('Science', 'NNP'),
#  ('platform', 'NN'),
#  ('.', '.')]

# %%
from nltk import ne_chunk

# Download the required resource for NER
nltk.download('maxent_ne_chunker_tab')
nltk.download('words') # This resource is also needed for the chunker

# Sample text
text = "Barack Obama was born in Hawaii in 1961."

# Tokenize and POS tag the sentence
tokens = word_tokenize(text)
tags = pos_tag(tokens)

# Apply Named Entity Recognition
entities = ne_chunk(tags)
print(entities)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\bisha\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\bisha\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# (S
#   (PERSON Barack/NNP)
#   (PERSON Obama/NNP)
#   was/VBD
#   born/VBN
#   in/IN
#   (GPE Hawaii/NNP)
#   in/IN
#   1961/CD
#   ./.)
