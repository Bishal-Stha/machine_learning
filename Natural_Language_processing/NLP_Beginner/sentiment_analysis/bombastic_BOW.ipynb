# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, ENGLISH_STOP_WORDS
import pandas as pd

movie = pd.read_csv("./../../NLP_Projects/IMDB Dataset.csv")
movie.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
text = " ".join(review for review in movie['review'])

# %%
my_stopwords = list(ENGLISH_STOP_WORDS.union(['film', 'movie', 'cinema', 'theatre']))

# %%
vex = TfidfVectorizer()

# %%
vect = CountVectorizer(stop_words=my_stopwords)

# vect.fit(movie.review)
# X = vect.transform(movie.review)

# Fit and transform the data
vect.fit(movie['review'])
X = vect.transform(movie['review'])

# %%
from nltk import word_tokenize

# %%
sentences = text[:1000]

tokens = [word_tokenize(sentence) for sentence in sentences]

# %%
article = "my life is #beautiful. It is full of #joy and #laughters. I am living my #life to the fullest. I meet people and they seem demotivated but i am always #enthusiastic about life."

# %%
import re
pattern = r"#\w+"
result = re.findall(pattern,article)
print(result)
# Out:
# ['#beautiful', '#joy', '#laughters', '#life', '#enthusiastic']

# %%
vect = CountVectorizer(token_pattern=pattern)

# %% [markdown]
# ### major features in CountVectorizer or TfidfVectorizer are
# - stop_words
# - ngram_range
# - token_pattern
# - max_df, min_df
# - max_features
